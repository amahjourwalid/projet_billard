# %%
import matplotlib 
import matplotlib.pyplot as plt 
from matplotlib import animation
import numpy as np 


angle = int(input( "Angle initial " ) )
long = int(input( "Longueur de la table " ) )
lim = int(input( "limite de taille du mot" ) )
compteur = 0


 def findIntersection(x1,y1,x2,y2,x3,y3,x4,y4):  ## intersection de deux droites basée sur 4 pts
        px= ( (x1*y2-y1*x2)*(x3-x4)-(x1-x2)*(x3*y4-y3*x4) ) / ( (x1-x2)*(y3-y4)-(y1-y2)*(x3-x4) ) 
        py= ( (x1*y2-y1*x2)*(y3-y4)-(y1-y2)*(x3*y4-y3*x4) ) / ( (x1-x2)*(y3-y4)-(y1-y2)*(x3-x4) )
                      return [px, py]





class bande :
    def position(parametre): ## prochaine position associée à l'angle ini
        
        return [x,y]
    
    
    def calcul_next(position, angle):
      
        vect_dir = [cos(angle)*(dist),sin(angle)*dist] ## dist est la distance parcourue par unité de temps par la boule
        next_angle = -angle ## snell-descartes
        
        ## on peut def next_position comme l'intersection du vecteur directeur 
        ## et de la droite de la bande suivante touchée, il faut doncprevoir cette dernière
        next_bande =              ## idée : chercher les 3 intersections possible et conserver celle du domaine admissible
        
          if next_bande  =    : ## l'une des quatres
                next_pos = findIntersection(position[0], position[1],vect_dir[0],vect_dir[1], 0,0,0,1)  ## cas de la bande gauche
            ## 3 if à faire
        
            
        return [next_bande, next_position, next_angle]       





class boule :
        
        def droite(point1, point2, parametre):
            return [x,y]
        
bande = bande_depart              
position = position_depart       #par ex (long/2,0)
vitesse =        ## echelle / seconde
t=0
trajectoire=[]
freq = 10        ## freq d'echantillonage
time = []         ## tous les temps à animer
points =[]        ## les coordonnées de chaque temps
mot = []          
angles_succ = []   ## le angles associés à chaque rebond

while(True):
    next_hit = bande.calcul_next(pos, angle)         
    point1 = next_hit[0].position(next_hit[1])       
    point2 = bande.position(position)
    length=distance(point1,point2)
    t_fin = t + length/vitesse
    time_temp = np.linspace(start=t, stop=t_fin, num=freq*(t_fin-t))
    
    
    for theta in time_temp:
        points = points + droite(point1,point2,(theta-t)/(t_fin-t))
        time = time + time_temp
        





for i in length(points):       ## creation du mot
    if( points[i][0] >= long or points[i][0] <=0 ):     
        compteur += 1
        mot.append("H")
        
        if( points[i][1]>= long or points[i][1] <= 0 ):  
        compteur += 1
        mot.append("V")
        
           if (compteur == lim):
                break
                
    return(mot)
        
         
    
    
        
        
    
    
        
        
fig = plt.figure() 
table = plt.axes(xlim=(0, long), ylim=(0, long) )     ## le domaine

def init():                          ## initialisation
    boule.set_data([], [])
    return boule,

def parcours(angle, long, fig,i):   ## la fonction à animer
    x,y = points[i]
    boule.set_data(points[i])
    return boule                 

anim  = animation.FuncAnimation(fig,parcours,init_func=initialise, blit=True )
# Out:
#   File "<ipython-input-4-c295c45f91c5>", line 13
#     def findIntersection(x1,y1,x2,y2,x3,y3,x4,y4):  ## intersection de deux droites basée sur 4 pts
#     ^
# IndentationError: unexpected indent
