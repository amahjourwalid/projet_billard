# %% [markdown]
# # Cas du billard ellitique

# %% [markdown]
# Le cas elliptique :
#
# Le modle  reste semblable : une bille rebondissant sans perte de vitesse et sans effet de friction dans l'ellipse.
# L'objectif est d'analyser les differences occasionnees par des changements sur les conditions initiales de l'experience, soient la position et orientation de la bille.
#
#
# Raellons que l'ellipse est un espace euclidien de dimension 2 où chaque point ossde une somme des distances aux deux foyers constante.
#
#
#     Cet espace verifie l'equation $x^2/a^2 + y^2/b^2 = 1$, avec a la longueur du grand rayon, b celle du petit.
#
# De nouveau, il est clair que les suivis de la bille risquent d'etre determines exclusivement par les conditions initiales ; il s'agit donc de generer ce tracer geometriquement.

# %%
###### import numpy as np
import math
def ball(xo,yo,mo):
	c=yo-mo*xo
	xn=(-mo*c*a*a+a*b*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	yn=(b*b*c+a*b*mo*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	if abs(xn-xo)<eps and abs(yn-yo)<eps :
		xn=(-mo*c*a*a-a*b*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
		yn=(b*b*c-a*b*mo*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	
	try :
		d=yn/xn*(a*a)/(b*b)-xn/yn*(b*b)/(a*a)
		mn=(2.0+d*mo)/(-d+2.0*mo)
	except ZeroDivisionError:
		mn=-mo
	
	return xn,yn,mn


a=2   
b=0.5
x0=0.707106781
y0=1.414213562
m0=3.0
#x0=1.0
#y0=0.0
#m0=-2.0
x1=0.0       ## our initialiser
y1=0.0
m1=0.0
eps=1.e-6
abs_succ=[]
ordsucc=[]
pentes_succ = []
ecarts_succ =[]
for i in range(100):
    x1,y1,m1=ball(x0,y0,m0)
   # print (i,x1,y1,m1,((x1-x0)**2+(y1-y0)**2)**0.5)
    pentes_succ.append(m1)
    abs_succ.append(x1)
    ordsucc.append(y1)
    ecarts_succ.append(((x1-x0)**2+(y1-y0)**2)**0.5)
    x0,y0,m0=x1,y1,m1
print ('done')


from matplotlib import pyplot as plt

plt.axis([-2, 2, -2, 2])

plt.plot(abs_succ,ordsucc)


x = np.arange(-2, 2, 0.01)
y=[]
for i in range(len(x)):
    y.append(b*math.sqrt(1-x[i]**2/a**2))
plt.plot(x,y,color ='red')    
plt.plot(x,np.negative(y),color ='red')
# Out:
# done

# %%
###### import numpy as np
import math
def ball(xo,yo,mo):
	c=yo-mo*xo
	xn=(-mo*c*a*a+a*b*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	yn=(b*b*c+a*b*mo*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	if abs(xn-xo)<eps and abs(yn-yo)<eps :
		xn=(-mo*c*a*a-a*b*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
		yn=(b*b*c-a*b*mo*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	
	try :
		d=yn/xn*(a*a)/(b*b)-xn/yn*(b*b)/(a*a)
		mn=(2.0+d*mo)/(-d+2.0*mo)
	except ZeroDivisionError:
		mn=-mo
	
	return xn,yn,mn


a=2.0   
b=1.0
x0=0.707106781
y0=1.414213562
m0=3.0
#x0=1.0
#y0=0.0
#m0=-2.0
x1=0.0       ## our initialiser
y1=0.0
m1=0.0
eps=1.e-6
abs_succ=[]
ordsucc=[]
pentes_succ = []
ecarts_succ =[]
for i in range(100):
    x1,y1,m1=ball(x0,y0,m0)
   # print (i,x1,y1,m1,((x1-x0)**2+(y1-y0)**2)**0.5)
    pentes_succ.append(m1)
    abs_succ.append(x1)
    ord_succ.append(y1)
    ecarts_succ.append(((x1-x0)**2+(y1-y0)**2)**0.5)
    x0,y0,m0=x1,y1,m1
print ('done')


from matplotlib import pyplot as plt

plt.axis([-2, 2, -2, 2])

plt.plot(abs_succ,ordsucc)


x = np.arange(-2, 2, 0.01)
y=[]
for i in range(len(x)):
    y.append(b*math.sqrt(1-x[i]**2/a**2))
plt.plot(x,y,color ='red')    
plt.plot(x,np.negative(y),color ='red')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-be23043e511a> in <module>
#      39     pentes_succ.append(m1)
#      40     abs_succ.append(x1)
# ---> 41     ord_succ.append(y1)
#      42     ecarts_succ.append(((x1-x0)**2+(y1-y0)**2)**0.5)
#      43     x0,y0,m0=x1,y1,m1
#
# NameError: name 'ord_succ' is not defined

# %%
###### import numpy as np
import math
def ball(xo,yo,mo):
	c=yo-mo*xo
	xn=(-mo*c*a*a+a*b*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	yn=(b*b*c+a*b*mo*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	if abs(xn-xo)<eps and abs(yn-yo)<eps :
		xn=(-mo*c*a*a-a*b*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
		yn=(b*b*c-a*b*mo*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	
	try :
		d=yn/xn*(a*a)/(b*b)-xn/yn*(b*b)/(a*a)
		mn=(2.0+d*mo)/(-d+2.0*mo)
	except ZeroDivisionError:
		mn=-mo
	
	return xn,yn,mn


a=2.0   
b=1.5
x0=0.707106781
y0=1.414213562
m0=3.0
#x0=1.0
#y0=0.0
#m0=-2.0
x1=0.0       ## our initialiser
y1=0.0
m1=0.0
eps=1.e-6
abs_succ=[]
ordsucc=[]
pentes_succ = []
ecarts_succ =[]
for i in range(100):
    x1,y1,m1=ball(x0,y0,m0)
   # print (i,x1,y1,m1,((x1-x0)**2+(y1-y0)**2)**0.5)
    pentes_succ.append(m1)
    abs_succ.append(x1)
    ord_succ.append(y1)
    ecarts_succ.append(((x1-x0)**2+(y1-y0)**2)**0.5)
    x0,y0,m0=x1,y1,m1
print ('done')


from matplotlib import pyplot as plt

plt.axis([-2, 2, -2, 2])

plt.plot(abs_succ,ord_succ)


x = np.arange(-2, 2, 0.01)
y=[]
for i in range(len(x)):
    y.append(b*math.sqrt(1-x[i]**2/a**2))
plt.plot(x,y,color ='red')    
plt.plot(x,np.negative(y),color ='red')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-d0cd44a0450c> in <module>
#      39     pentes_succ.append(m1)
#      40     abs_succ.append(x1)
# ---> 41     ord_succ.append(y1)
#      42     ecarts_succ.append(((x1-x0)**2+(y1-y0)**2)**0.5)
#      43     x0,y0,m0=x1,y1,m1
#
# NameError: name 'ord_succ' is not defined

# %%
import math
def ball(xo,yo,mo):
	c=yo-mo*xo
	xn=(-mo*c*a*a+a*b*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	yn=(b*b*c+a*b*mo*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	if abs(xn-xo)<eps and abs(yn-yo)<eps :
		xn=(-mo*c*a*a-a*b*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
		yn=(b*b*c-a*b*mo*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	
	try :
		d=yn/xn*(a*a)/(b*b)-xn/yn*(b*b)/(a*a)
		mn=(2.0+d*mo)/(-d+2.0*mo)
	except ZeroDivisionError:
		mn=-mo
	
	return xn,yn,mn


a=2.0   
b=1.5
x0=0.707106781
y0=1.414213562
m0=3.0
#x0=1.0
#y0=0.0
#m0=-2.0
x1=0.0       ## our initialiser
y1=0.0
m1=0.0
eps=1.e-6
abs_succ=[]
ord_succ=[]
pentes_succ = []
ecarts_succ =[]
for i in range(100):
    x1,y1,m1=ball(x0,y0,m0)
   # print (i,x1,y1,m1,((x1-x0)**2+(y1-y0)**2)**0.5)
    pentes_succ.append(m1)
    abs_succ.append(x1)
    ord_succ.append(y1)
    ecarts_succ.append(((x1-x0)**2+(y1-y0)**2)**0.5)
    x0,y0,m0=x1,y1,m1
print ('done')

comp1 = abs_succ[0:98]
comp2 = abs_succ[1:99]
plt.plot(comp1,comp2)
# Out:
# done

# %% [markdown]
# On est de plus en plus convaincu par le  caractre  non chaotique du billard.
# ar exmele, les autres correlations entre coordonnees :

# %%
import math
def ball(xo,yo,mo):
	c=yo-mo*xo
	xn=(-mo*c*a*a+a*b*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	yn=(b*b*c+a*b*mo*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	if abs(xn-xo)<eps and abs(yn-yo)<eps :
		xn=(-mo*c*a*a-a*b*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
		yn=(b*b*c-a*b*mo*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	
	try :
		d=yn/xn*(a*a)/(b*b)-xn/yn*(b*b)/(a*a)
		mn=(2.0+d*mo)/(-d+2.0*mo)
	except ZeroDivisionError:
		mn=-mo
	
	return xn,yn,mn


a=2.0   
b=1.5
x0=0.707106781
y0=1.414213562
m0=3.0
#x0=1.0
#y0=0.0
#m0=-2.0
x1=0.0       ## our initialiser
y1=0.0
m1=0.0
eps=1.e-6
abs_succ=[]
ordsucc=[]
pentes_succ = []
ecarts_succ =[]
for i in range(100):
    x1,y1,m1=ball(x0,y0,m0)
   # print (i,x1,y1,m1,((x1-x0)**2+(y1-y0)**2)**0.5)
    pentes_succ.append(m1)
    abs_succ.append(x1)
    ord_succ.append(y1)
    ecarts_succ.append(((x1-x0)**2+(y1-y0)**2)**0.5)
    x0,y0,m0=x1,y1,m1
print ('done')

comp1 = abs_succ[0:97]
comp2 = abs_succ[2:99]

plt.plot(comp1,comp2)
# Out:
# done

# %%
import math
def ball(xo,yo,mo):
	c=yo-mo*xo
	xn=(-mo*c*a*a+a*b*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	yn=(b*b*c+a*b*mo*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	if abs(xn-xo)<eps and abs(yn-yo)<eps :
		xn=(-mo*c*a*a-a*b*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
		yn=(b*b*c-a*b*mo*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	
	try :
		d=yn/xn*(a*a)/(b*b)-xn/yn*(b*b)/(a*a)
		mn=(2.0+d*mo)/(-d+2.0*mo)
	except ZeroDivisionError:
		mn=-mo
	
	return xn,yn,mn


a=2.0   
b=1.5
x0=0.707106781
y0=1.414213562
m0=3.0
#x0=1.0
#y0=0.0
#m0=-2.0
x1=0.0       ## our initialiser
y1=0.0
m1=0.0
eps=1.e-6
abs_succ=[]
ord_succ=[]
pentes_succ = []
ecarts_succ =[]
for i in range(100):
    x1,y1,m1=ball(x0,y0,m0)
   # print (i,x1,y1,m1,((x1-x0)**2+(y1-y0)**2)**0.5)
    pentes_succ.append(m1)
    abs_succ.append(x1)
    ord_succ.append(y1)
    ecarts_succ.append(((x1-x0)**2+(y1-y0)**2)**0.5)
    x0,y0,m0=x1,y1,m1
print ('done')

comp1 = abs_succ[0:96]
comp2 = abs_succ[3:99]
plt.plot(comp1,comp2)
# Out:
# done

# %% [markdown]
# Finalement, les xn-yn :

# %%
import math
import numpy as np
def ball(xo,yo,mo):
	c=yo-mo*xo
	xn=(-mo*c*a*a+a*b*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	yn=(b*b*c+a*b*mo*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	if abs(xn-xo)<eps and abs(yn-yo)<eps :
		xn=(-mo*c*a*a-a*b*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
		yn=(b*b*c-a*b*mo*(a*a*mo*mo+b*b-c*c)**0.5)/(a*a*mo*mo+b*b)
	
	try :
		d=yn/xn*(a*a)/(b*b)-xn/yn*(b*b)/(a*a)
		mn=(2.0+d*mo)/(-d+2.0*mo)
	except ZeroDivisionError:
		mn=-mo
	
	return xn,yn,mn


a=2.0   
b=1.5
x0=0.707106781
y0=1.414213562
m0=3.0
#x0=1.0
#y0=0.0
#m0=-2.0
x1=0.0       ## our initialiser
y1=0.0
m1=0.0
eps=1.e-6
abs_succ=[]
ord_succ=[]
pentes_succ = []
ecarts_succ =[]
for i in range(100):
    x1,y1,m1=ball(x0,y0,m0)
   # print (i,x1,y1,m1,((x1-x0)**2+(y1-y0)**2)**0.5)
    pentes_succ.append(m1)
    abs_succ.append(x1)
    ord_succ.append(y1)
    ecarts_succ.append(((x1-x0)**2+(y1-y0)**2)**0.5)
    x0,y0,m0=x1,y1,m1
print ('done')

newlist = np.array([e-ordsucc[c] for c,e in enumerate(abs_succ)])
plt.plot(abs_succ,newlist)
# Out:
# done

# %% [markdown]
# Autres curiosites :
